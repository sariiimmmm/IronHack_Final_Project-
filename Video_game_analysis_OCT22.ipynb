# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
vg1=pd.read_csv("Data/vgsales.csv")
vg1
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
vg2=pd.read_csv("Data/game_sales_data.csv", encoding = "ISO-8859-1")
vg2
# Out:
#         Rank                                               Name Platform  \
# 0          1                                         Wii Sports      Wii
# 1          2                                  Super Mario Bros.      NES
# 2          3                   Counter-Strike: Global Offensive       PC
# 3          4                                     Mario Kart Wii      Wii
# 4          5                      PLAYERUNKNOWN'S BATTLEGROUNDS       PC
# ...      ...                                                ...      ...
# 19595  19594  FirePower for Microsoft Combat Flight Simulator 3       PC
# 19596  19595                         Tom Clancy's Splinter Cell       PC
# 19597  19596             Ashita no Joe 2: The Anime Super Remix      PS2
# 19598  19597               Tokyo Yamanote Boys for V: Main Disc      PSV
# 19599  19598             NadePro!! Kisama no Seiyuu Yatte Miro!      PS2
#
#               Publisher              Developer  Critic_Score  User_Score  \
# ...

# %%
vg_final=pd.concat([vg1, vg2], axis=0)
vg_final
# Out:
#         Rank                                               Name Platform  \
# 0          1                                         Wii Sports      Wii
# 1          2                                  Super Mario Bros.      NES
# 2          3                                     Mario Kart Wii      Wii
# 3          4                                  Wii Sports Resort      Wii
# 4          5                           Pokemon Red/Pokemon Blue       GB
# ...      ...                                                ...      ...
# 19595  19594  FirePower for Microsoft Combat Flight Simulator 3       PC
# 19596  19595                         Tom Clancy's Splinter Cell       PC
# 19597  19596             Ashita no Joe 2: The Anime Super Remix      PS2
# 19598  19597               Tokyo Yamanote Boys for V: Main Disc      PSV
# 19599  19598             NadePro!! Kisama no Seiyuu Yatte Miro!      PS2
#
#          Year         Genre  Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
vg_finl=vg_final.drop_duplicates(subset="Name", inplace=True)

# %%
vg_final.reset_index()
# Out:
#        index   Rank                                               Name  \
# 0          0      1                                         Wii Sports
# 1          1      2                                  Super Mario Bros.
# 2          2      3                                     Mario Kart Wii
# 3          3      4                                  Wii Sports Resort
# 4          4      5                           Pokemon Red/Pokemon Blue
# ...      ...    ...                                                ...
# 14094  19593  19592  Nintama Rantarou: Nintama no Tame no Ninjutsu ...
# 14095  19595  19594  FirePower for Microsoft Combat Flight Simulator 3
# 14096  19597  19596             Ashita no Joe 2: The Anime Super Remix
# 14097  19598  19597               Tokyo Yamanote Boys for V: Main Disc
# 14098  19599  19598             NadePro!! Kisama no Seiyuu Yatte Miro!
#
#       Platform    Year         Genre  Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
vg3=pd.read_csv("Data/steam_games.csv")
vg3
# Out:
# /var/folders/pl/nx9y_yvn699gd60j5xnq21x80000gn/T/ipykernel_59821/3420382485.py:1: DtypeWarning: Columns (53) have mixed types. Specify dtype option on import or set low_memory=False.
#   vg3=pd.read_csv("Data/steam_games.csv")
#             id                                      name  \
# 0           10                            Counter-Strike
# 1           20                     Team Fortress Classic
# 2           30                             Day of Defeat
# 3           40                        Deathmatch Classic
# 4           50                 Half-Life: Opposing Force
# ...        ...                                       ...
# 66209  1969810                    Enter the Chronosphere
# 66210  1972920                              Wife Massage
# 66211  1972970                       Late photographer 4
# 66212  1973220                           Succubus Racing
# 66213  1973640  The Divine Speaker: The Sun and the Moon
#
# ...

# %%
vg3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 66214 entries, 0 to 66213
# Data columns (total 65 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   id                          66214 non-null  int64
#  1   name                        66214 non-null  object
#  2   detailed_description        66190 non-null  object
#  3   about_the_game              66189 non-null  object
#  4   short_description           66190 non-null  object
#  5   header_image                66214 non-null  object
#  6   developers                  66214 non-null  object
#  7   publishers                  66214 non-null  object
#  8   platforms                   66214 non-null  object
#  9   release_date                66214 non-null  object
#  10  initialprice                66214 non-null  object
#  11  drm                         66214 non-null  bool
#  12  ext_user_account_notice     66214 non-null  object
# ...

# %%
keep_column=["id","name","genres", "publishers","platforms", "release_date","total_reviews", "playtime_mean_forever",
           "playtime_median_forever", "Tags - Players", "online", "Tags - Visuals & Viewpoint","singleplayer", "multiplayer" ]

# %%
vg4=vg3[keep_column]

# %%
vg4
# Out:
#             id                                      name  \
# 0           10                            Counter-Strike
# 1           20                     Team Fortress Classic
# 2           30                             Day of Defeat
# 3           40                        Deathmatch Classic
# 4           50                 Half-Life: Opposing Force
# ...        ...                                       ...
# 66209  1969810                    Enter the Chronosphere
# 66210  1972920                              Wife Massage
# 66211  1972970                       Late photographer 4
# 66212  1973220                           Succubus Racing
# 66213  1973640  The Divine Speaker: The Sun and the Moon
#
#                             genres                  publishers  \
# 0                           Action                   ['Valve']
# 1                           Action                   ['Valve']
# 2                           Action                   ['Valve']
# ...

# %%
vg4["release_date"]=vg4["release_date"].apply(lambda x : x[0].str.split('-') if x[0].str.contains('-') else x)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [46], in <cell line: 1>()
# ----> 1 vg4["release_date"]=vg4["release_date"].apply(lambda x : x[0].str.split('-') if x[0].str.contains('-') else x)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/series.py:4433, in Series.apply(self, func, convert_dtype, args, **kwargs)
#    4323 def apply(
#    4324     self,
#    4325     func: AggFuncType,
#    (...)
#    4328     **kwargs,
#    4329 ) -> DataFrame | Series:
#    4330     """
#    4331     Invoke function on values of Series.
#    4332
#    (...)
#    4431     dtype: float64
#    4432     """
# -> 4433     return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/apply.py:1082, in SeriesApply.apply(self)
#    1078 if isinstance(self.f, str):
# ...

# %%
vg4["release_date"]=vg4["release_date"].apply(lambda x: 0 if x=="coming_soon" else x)
# Out:
# /var/folders/pl/nx9y_yvn699gd60j5xnq21x80000gn/T/ipykernel_59821/4280225524.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vg4["release_date"]=vg4["release_date"].apply(lambda x: 0 if x=="coming_soon" else x)

# %%
vg4
# Out:
#             id                                      name  \
# 0           10                            Counter-Strike
# 1           20                     Team Fortress Classic
# 2           30                             Day of Defeat
# 3           40                        Deathmatch Classic
# 4           50                 Half-Life: Opposing Force
# ...        ...                                       ...
# 66209  1969810                    Enter the Chronosphere
# 66210  1972920                              Wife Massage
# 66211  1972970                       Late photographer 4
# 66212  1973220                           Succubus Racing
# 66213  1973640  The Divine Speaker: The Sun and the Moon
#
#                             genres                  publishers  \
# 0                           Action                   ['Valve']
# 1                           Action                   ['Valve']
# 2                           Action                   ['Valve']
# ...

# %%
vg4["release_date"]=vg4["release_date"].str.split('-')
# Out:
# /var/folders/pl/nx9y_yvn699gd60j5xnq21x80000gn/T/ipykernel_59821/671830128.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vg4["release_date"]=vg4["release_date"].str.split('-')

# %%
vg4["publishers"]=vg4["publishers"].map(lambda x: x.lstrip("['").rstrip("']"))
# Out:
# /var/folders/pl/nx9y_yvn699gd60j5xnq21x80000gn/T/ipykernel_59821/329313586.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vg4["publishers"]=vg4["publishers"].map(lambda x: x.lstrip("['").rstrip("']"))

# %%
# Out:
#             id                                      name  \
# 0           10                            Counter-Strike
# 1           20                     Team Fortress Classic
# 2           30                             Day of Defeat
# 3           40                        Deathmatch Classic
# 4           50                 Half-Life: Opposing Force
# ...        ...                                       ...
# 66209  1969810                    Enter the Chronosphere
# 66210  1972920                              Wife Massage
# 66211  1972970                       Late photographer 4
# 66212  1973220                           Succubus Racing
# 66213  1973640  The Divine Speaker: The Sun and the Moon
#
#                             genres              publishers  \
# 0                           Action                   Valve
# 1                           Action                   Valve
# 2                           Action                   Valve
# ...
